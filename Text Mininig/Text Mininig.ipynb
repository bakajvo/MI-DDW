# %%
import nltk
from nltk.corpus import stopwords
from string import punctuation
import wikipedia
import pandas as pd
from collections import Counter

# %%
#nltk.download()

# %%
pd.options.display.max_rows = 100

# %%
text = None
with open('data.txt', 'r') as f:
    text = f.read()

# %%
def preprocessText(text):
    tokens = nltk.word_tokenize(text)
    tokens = [t.replace("â€™", "'") for t in tokens]
    stops = stopwords.words('english')
    filtered_tokens = [token for token in tokens if token not in punctuation]
    filtered_tokens = [token for token in filtered_tokens if token not in stops]
    return filtered_tokens

# %%
tokens = preprocessText(text)

# %%
tagged = nltk.pos_tag(tokens)
tagged
# Out:
# [('Sending', 'VBG'),
#  ('astronauts', 'NNS'),
#  ('back', 'RB'),
#  ('moon', 'VBP'),
#  ('one', 'CD'),
#  ('top', 'JJ'),
#  ('space', 'NN'),
#  ('priorities', 'NNS'),
#  ('President', 'NNP'),
#  ('Trump', 'NNP'),
#  ('But', 'CC'),
#  ('administration', 'NN'),
#  ('wants', 'VBZ'),
#  ('accomplish', 'JJ'),
#  ('without', 'IN'),
#  ('giving', 'VBG'),
#  ('NASA', 'NNP'),
#  ('additional', 'JJ'),
#  ('money', 'NN'),
#  ('occur', 'VBP'),
#  ('leaves', 'VBZ'),
#  ('office', 'NN'),
#  ('even', 'RB'),
#  ('wins', 'VBZ'),
#  ('re-election', 'NN'),
#  ('Instead', 'RB'),
#  ('aims', 'VBZ'),
#  ('give', 'JJ'),
#  ('private', 'JJ'),
#  ('sector', 'NN'),
#  ('greater', 'JJR'),
#  ('role', 'NN'),
#  ('according', 'VBG'),
#  ('budget', 'NN'),
#  ('proposal', 'NN'),
#  ('released', 'VBN'),
#  ('Monday', 'NNP'),
#  ('The', 'DT'),
#  ('administration', 'NN'),
#  ('also', 'RB'),
#  ('looking', 'VBG'),
#  ('end', 'JJ'),
#  ('American', 'JJ'),
#  ('payments', 'NNS'),
#  ('International', 'NNP'),
#  ('Space', 'NNP'),
#  ('Station', 'NNP'),
#  ('2025', 'CD'),
#  ('The', 'DT'),
#  ('space', 'NN'),
#  ('station', 'NN'),
#  ('currently', 'RB'),
#  ('scheduled', 'VBN'),
#  ('operate', 'NN'),
#  ('2024', 'CD'),
#  ('expectation', 'NN'),
#  ('would', 'MD'),
#  ('extended', 'VB'),
#  ('least', 'NN'),
#  ('2028', 'CD'),
#  ('According', 'VBG'),
#  ('excerpts', 'NNS'),
#  ('NASA', 'NNP'),
#  ('documents', 'NNS'),
#  ('obtained', 'VBD'),
#  ('The', 'DT'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('Times', 'NNP'),
#  ("budget's", 'JJ'),
#  ('release', 'NN'),
#  ('administration', 'NN'),
#  ('propose', 'RB'),
#  ('19.9', 'CD'),
#  ('billion', 'CD'),
#  ('spending', 'NN'),
#  ('space', 'NN'),
#  ('agency', 'NN'),
#  ('fiscal', 'JJ'),
#  ('year', 'NN'),
#  ('2019', 'CD'),
#  ('begins', 'VBZ'),
#  ('Oct.', 'NNP'),
#  ('1', 'CD'),
#  ('That', 'IN'),
#  ('370', 'CD'),
#  ('million', 'CD'),
#  ('increase', 'NN'),
#  ('current', 'JJ'),
#  ('year', 'NN'),
#  ('result', 'NN'),
#  ('budget', 'NN'),
#  ('deal', 'NN'),
#  ('reached', 'VBD'),
#  ('Congress', 'NNP'),
#  ('last', 'JJ'),
#  ('week', 'NN'),
#  ('signed', 'VBD'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('The', 'DT'),
#  ('budget', 'NN'),
#  ('numbers', 'NNS'),
#  ('confirmed', 'VBD'),
#  ('person', 'NN'),
#  ('authorized', 'VBN'),
#  ('talk', 'NN'),
#  ('publicly', 'RB'),
#  ('In', 'IN'),
#  ('future', 'JJ'),
#  ('years', 'NNS'),
#  ('administration', 'NN'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ("NASA's", 'NNP'),
#  ('spending', 'VBG'),
#  ('drop', 'NN'),
#  ('19.6', 'CD'),
#  ('billion', 'CD'),
#  ('stay', 'NNS'),
#  ('flat', 'JJ'),
#  ('2023', 'CD'),
#  ('With', 'IN'),
#  ('inflation', 'NN'),
#  ("NASA's", 'NNP'),
#  ('buying', 'NN'),
#  ('power', 'NN'),
#  ('would', 'MD'),
#  ('erode', 'VB'),
#  ('effectively', 'RB'),
#  ('budget', 'NN'),
#  ('cut', 'NN'),
#  ('year', 'NN'),
#  ('Continue', 'NNP'),
#  ('reading', 'NN'),
#  ('main', 'JJ'),
#  ('story', 'NN'),
#  ('RELATED', 'NNP'),
#  ('COVERAGE', 'NNP'),
#  ('If', 'IN'),
#  ('No', 'DT'),
#  ('One', 'NNP'),
#  ('Owns', 'NNP'),
#  ('Moon', 'NNP'),
#  ('Can', 'MD'),
#  ('Anyone', 'VB'),
#  ('Make', 'NNP'),
#  ('Money', 'NNP'),
#  ('Up', 'IN'),
#  ('There', 'EX'),
#  ('NOV.', 'NNP'),
#  ('26', 'CD'),
#  ('2017', 'CD'),
#  ('Falcon', 'NNP'),
#  ('Heavy', 'NNP'),
#  ('Roar', 'NNP'),
#  ('Thunder', 'NNP'),
#  ('Carries', 'NNP'),
#  ("SpaceX's", 'NNP'),
#  ('Ambition', 'NNP'),
#  ('Into', 'NNP'),
#  ('Orbit', 'NNP'),
#  ('FEB.', 'NNP'),
#  ('6', 'CD'),
#  ('2018', 'CD'),
#  ('The', 'DT'),
#  ('Google', 'NNP'),
#  ('Lunar', 'NNP'),
#  ('X', 'NNP'),
#  ("Prize's", 'NNP'),
#  ('Race', 'NNP'),
#  ('Moon', 'NNP'),
#  ('Is', 'VBZ'),
#  ('Over', 'IN'),
#  ('Nobody', 'NNP'),
#  ('Won', 'NNP'),
#  ('JAN.', 'NNP'),
#  ('23', 'CD'),
#  ('2018', 'CD'),
#  ('RECENT', 'NNP'),
#  ('COMMENTS', 'NNP'),
#  ('Bill', 'NNP'),
#  ('February', 'NNP'),
#  ('13', 'CD'),
#  ('2018', 'CD'),
#  ('Predictably', 'NNP'),
#  ('Trump', 'NNP'),
#  ('regime', 'NN'),
#  ('slashing', 'VBG'),
#  ('NASA', 'NNP'),
#  ('funding', 'NN'),
#  ('related', 'JJ'),
#  ('way', 'NN'),
#  ('protecting', 'VBG'),
#  ('environment', 'NN'),
#  ('I', 'PRP'),
#  ('would', 'MD'),
#  ('favor', 'VB'),
#  ('one', 'CD'),
#  ('way', 'NN'),
#  ('mission', 'NN'),
#  ('...', ':'),
#  ('paulie', 'VBP'),
#  ('February', 'NNP'),
#  ('13', 'CD'),
#  ('2018', 'CD'),
#  ('The', 'DT'),
#  ('head', 'NN'),
#  ('NASA', 'NNP'),
#  ('absolutely', 'RB'),
#  ('unqualified', 'JJ'),
#  ('Climate', 'NNP'),
#  ('change', 'NN'),
#  ('denier', 'NN'),
#  ('ex', 'FW'),
#  ('Navy', 'NNP'),
#  ('pilot', 'NN'),
#  ('As', 'IN'),
#  ('line', 'NN'),
#  ('mechanic', 'JJ'),
#  ('major', 'JJ'),
#  ('airline', 'NN'),
#  ('30', 'CD'),
#  ('years', 'NNS'),
#  ('...', ':'),
#  ('siestaderek', 'RB'),
#  ('February', 'NNP'),
#  ('13', 'CD'),
#  ('2018', 'CD'),
#  ('Who', 'NNP'),
#  ('cares', 'VBZ'),
#  ('Elon', 'NNP'),
#  ('Musk', 'NNP'),
#  ('sending', 'VBG'),
#  ('us', 'PRP'),
#  ('Mars', 'NNP'),
#  ('anyways', 'VBZ'),
#  ('SEE', 'NNP'),
#  ('ALL', 'NNP'),
#  ('COMMENTS', 'NNP'),
#  ('A', 'NNP'),
#  ('NASA', 'NNP'),
#  ('spokesman', 'NN'),
#  ('said', 'VBD'),
#  ('could', 'MD'),
#  ('discuss', 'VB'),
#  ('budget', 'NN'),
#  ('proposal', 'NN'),
#  ('released', 'VBD'),
#  ('The', 'DT'),
#  ('proposal', 'NN'),
#  ('opening', 'VBG'),
#  ('bid', 'NN'),
#  ('Congress', 'NNP'),
#  ('decides', 'VBZ'),
#  ('final', 'JJ'),
#  ('spending', 'NN'),
#  ('numbers', 'NNS'),
#  ('sometimes', 'RB'),
#  ('adjusting', 'VBG'),
#  ('ignoring', 'VBG'),
#  ("president's", 'JJ'),
#  ('priorities', 'NNS'),
#  ('But', 'CC'),
#  ("administration's", 'JJ'),
#  ('wishes', 'NNS'),
#  ('often', 'RB'),
#  ('incorporated', 'JJ'),
#  ("NASA's", 'NNP'),
#  ('budget', 'NN'),
#  ('announced', 'VBD'),
#  ('moment', 'NN'),
#  ('agency', 'NN'),
#  ('permanent', 'JJ'),
#  ('leaders', 'NNS'),
#  ('carry', 'VBP'),
#  ('new', 'JJ'),
#  ('directions', 'NNS'),
#  ('Mr.', 'NNP'),
#  ('Trump', 'NNP'),
#  ('nominated', 'VBD'),
#  ('Jim', 'NNP'),
#  ('Bridenstine', 'NNP'),
#  ('Oklahoma', 'NNP'),
#  ('congressman', 'NN'),
#  ('next', 'JJ'),
#  ('administrator', 'NN'),
#  ('Senate', 'NNP'),
#  ('yet', 'RB'),
#  ('confirmed', 'VBD'),
#  ('Whether', 'NNP'),
#  ('administration', 'NN'),
#  ('votes', 'NNS'),
#  ('confirm', 'VBP'),
#  ('remains', 'VBZ'),
#  ('uncertain', 'JJ'),
#  ('This', 'DT'),
#  ('far', 'RB'),
#  ('longest', 'JJ'),
#  ('period', 'NN'),
#  ("NASA's", 'NNP'),
#  ('history', 'NN'),
#  ('without', 'IN'),
#  ('administrator', 'NN'),
#  ('Additionally', 'NNP'),
#  ('one', 'CD'),
#  ('nominated', 'VBD'),
#  ('No', 'DT'),
#  ('2', 'CD'),
#  ('position', 'NN'),
#  ('deputy', 'NN'),
#  ('administrator', 'NN'),
#  ('The', 'DT'),
#  ('Trump', 'NNP'),
#  ('administration', 'NN'),
#  ('also', 'RB'),
#  ('established', 'VBD'),
#  ('National', 'NNP'),
#  ('Space', 'NNP'),
#  ('Council', 'NNP'),
#  ('led', 'VBD'),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('Mike', 'NNP'),
#  ('Pence', 'NNP'),
#  ('coordinate', 'JJ'),
#  ('space', 'NN'),
#  ('policy', 'NN'),
#  ('military', 'JJ'),
#  ('civilian', 'JJ'),
#  ('agencies', 'NNS'),
#  ('The', 'DT'),
#  ('council', 'NN'),
#  ('held', 'VBD'),
#  ('first', 'JJ'),
#  ('public', 'JJ'),
#  ('meeting', 'NN'),
#  ('October', 'NNP'),
#  ('meet', 'NNP'),
#  ('month', 'NN'),
#  ('The', 'DT'),
#  ('Trump', 'NNP'),
#  ('administration', 'NN'),
#  ('also', 'RB'),
#  ('looking', 'VBG'),
#  ('trim', 'JJ'),
#  ('budget', 'NN'),
#  ("NASA's", 'NNP'),
#  ('earth', 'NN'),
#  ('science', 'NN'),
#  ('directorate', 'NN'),
#  ('includes', 'VBZ'),
#  ('climate', 'VBP'),
#  ('research', 'NN'),
#  ('cancel', 'NN'),
#  ('several', 'JJ'),
#  ('spacecraft', 'NN'),
#  ('like', 'IN'),
#  ('Plankton', 'NNP'),
#  ('Aerosol', 'NNP'),
#  ('Cloud', 'NNP'),
#  ('Ocean', 'NNP'),
#  ('Ecosystem', 'NNP'),
#  ('mission', 'VBD'),
#  ('The', 'DT'),
#  ('nearly', 'RB'),
#  ('1.8', 'CD'),
#  ('billion', 'CD'),
#  ('budget', 'NN'),
#  ('part', 'NN'),
#  ('NASA', 'NNP'),
#  ('would', 'MD'),
#  ('6.5', 'CD'),
#  ('percent', 'NN'),
#  ('lower', 'JJR'),
#  ('enacted', 'VBN'),
#  ('fiscal', 'JJ'),
#  ('year', 'NN'),
#  ('2017', 'CD'),
#  ('The', 'DT'),
#  ('Trump', 'NNP'),
#  ('administration', 'NN'),
#  ('also', 'RB'),
#  ('wants', 'VBZ'),
#  ('end', 'JJ'),
#  ('education', 'NN'),
#  ('programs', 'NNS'),
#  ('Similar', 'NNP'),
#  ('proposals', 'NNS'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ('disregarded', 'VBD'),
#  ('Congress', 'NNP'),
#  ('The', 'DT'),
#  ('astrophysics', 'NNS'),
#  ('division', 'NN'),
#  ('would', 'MD'),
#  ('cut', 'VB'),
#  ('12', 'CD'),
#  ('percent', 'NN'),
#  ('overall', 'JJ'),
#  ('budget', 'NN'),
#  ('would', 'MD'),
#  ('give', 'VB'),
#  ('increase', 'NN'),
#  ("NASA's", 'NNP'),
#  ('science', 'NN'),
#  ('directorate', 'NN'),
#  ('primarily', 'RB'),
#  ('robotic', 'JJ'),
#  ('planetary', 'JJ'),
#  ('missions', 'NNS'),
#  ('Rumors', 'NNPS'),
#  ('intent', 'JJ'),
#  ('end', 'NN'),
#  ('space', 'NN'),
#  ('station', 'NN'),
#  ('financing', 'NN'),
#  ('recently', 'RB'),
#  ('reported', 'VBD'),
#  ('The', 'DT'),
#  ('Verge', 'NNP'),
#  ('outlets', 'NNS'),
#  ('drawing', 'VBG'),
#  ('strong', 'JJ'),
#  ('criticism', 'NN'),
#  ('lawmakers', 'NNS'),
#  ('including', 'VBG'),
#  ('key', 'JJ'),
#  ('Republicans', 'NNPS'),
#  ('I', 'PRP'),
#  ('hope', 'VBP'),
#  ('reports', 'NNS'),
#  ('prove', 'VB'),
#  ('unfounded', 'JJ'),
#  ('Bigfoot', 'NNP'),
#  ('Senator', 'NNP'),
#  ('Ted', 'NNP'),
#  ('Cruz', 'NNP'),
#  ('Republican', 'NNP'),
#  ('Texas', 'NNP'),
#  ('chairman', 'NN'),
#  ('Senate', 'NNP'),
#  ('Subcommittee', 'NNP'),
#  ('Space', 'NNP'),
#  ('Science', 'NNP'),
#  ('Competitiveness', 'NNP'),
#  ('said', 'VBD'),
#  ('Wednesday', 'NNP'),
#  ('Federal', 'NNP'),
#  ('Aviation', 'NNP'),
#  ('Administration', 'NNP'),
#  ('conference', 'NN'),
#  ('commercial', 'JJ'),
#  ('space', 'NN'),
#  ('transportation', 'NN'),
#  ('He', 'PRP'),
#  ('decried', 'VBD'),
#  ('â€śnumbskullsâ€ť', 'NNP'),
#  ('Office', 'NNP'),
#  ('Management', 'NNP'),
#  ('Budget', 'NNP'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('coming', 'VBG'),
#  ('idea', 'NN'),
#  ('â€śAs', 'NNP'),
#  ('fiscal', 'JJ'),
#  ('conservative', 'JJ'),
#  ('know', 'VBP'),
#  ('one', 'CD'),
#  ('dumbest', 'JJS'),
#  ('things', 'NNS'),
#  ('â€ť', 'NNP'),
#  ('said', 'VBD'),
#  ('â€śCanceling', 'VBG'),
#  ('programs', 'NNS'),
#  ('billions', 'NNS'),
#  ('investment', 'NN'),
#  ('still', 'RB'),
#  ('serious', 'JJ'),
#  ('usable', 'JJ'),
#  ('life', 'NN'),
#  ('it.â€ť', 'VBZ'),
#  ('The', 'DT'),
#  ('conference', 'NN'),
#  ('attended', 'VBD'),
#  ('Scott', 'NNP'),
#  ('Pace', 'NNP'),
#  ('executive', 'NN'),
#  ('secretary', 'NN'),
#  ('Mr.', 'NNP'),
#  ("Pence's", 'NNP'),
#  ('space', 'NN'),
#  ('council', 'NN'),
#  ('While', 'IN'),
#  ('discuss', 'NN'),
#  ('details', 'NNS'),
#  ('budget', 'NN'),
#  ('Mr.', 'NNP'),
#  ('Pace', 'NNP'),
#  ('suggested', 'VBD'),
#  ('money', 'NN'),
#  ('needed', 'VBN'),
#  ('freed', 'VBP'),
#  ('new', 'JJ'),
#  ('initiatives', 'NNS'),
#  ('For', 'IN'),
#  ('NASA', 'NNP'),
#  ('push', 'NN'),
#  ('human', 'NN'),
#  ('spaceflight', 'NN'),
#  ('said', 'VBD'),
#  ('â€śthe', 'JJ'),
#  ('kinds', 'NNS'),
#  ('commitment', 'JJ'),
#  ('resources', 'NNS'),
#  ('traditionally', 'RB'),
#  ("we've", 'VBP'),
#  ('done', 'VBN'),
#  ('low-earth', 'JJ'),
#  ('orbit', 'NN'),
#  ('direct', 'JJ'),
#  ('toward', 'IN'),
#  ('deeper', 'JJR'),
#  ('space', 'NN'),
#  ('exploration.â€ť', 'IN'),
#  ('The', 'DT'),
#  ('budget', 'NN'),
#  ('proposal', 'NN'),
#  ('promises', 'VBZ'),
#  ('â€śa', 'NNP'),
#  ('seamless', 'NN'),
#  ('transition', 'NN'),
#  ('use', 'NN'),
#  ('future', 'JJ'),
#  ('commercial', 'JJ'),
#  ('capabilities', 'NNS'),
#  ('â€ť', 'VBP'),
#  ('allocates', 'VBZ'),
#  ('150', 'CD'),
#  ('million', 'CD'),
#  ('2019', 'CD'),
#  ('encourage', 'NN'),
#  ('commercial', 'JJ'),
#  ('development', 'NN'),
#  ('low-Earth', 'JJ'),
#  ('orbit', 'NN'),
#  ('The', 'DT'),
#  ('administration', 'NN'),
#  ('proposes', 'VBZ'),
#  ('900', 'CD'),
#  ('million', 'CD'),
#  ('goal', 'NN'),
#  ('2023', 'CD'),
#  ('If', 'IN'),
#  ('structured', 'VBN'),
#  ('like', 'IN'),
#  ('earlier', 'JJR'),
#  ('NASA', 'NNP'),
#  ('public-private', 'JJ'),
#  ('partnerships', 'NNS'),
#  ('like', 'IN'),
#  ('ones', 'NNS'),
#  ('carrying', 'VBG'),
#  ('cargo', 'NN'),
#  ('crew', 'VBD'),
#  ('space', 'NN'),
#  ('station', 'NN'),
#  ('money', 'NN'),
#  ('would', 'MD'),
#  ('split', 'VB'),
#  ('two', 'CD'),
#  ('companies', 'NNS'),
#  ('By', 'IN'),
#  ('contrast', 'NN'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('spent', 'VBD'),
#  ('close', 'RB'),
#  ('100', 'CD'),
#  ('billion', 'CD'),
#  ('building', 'NN'),
#  ('operating', 'VBG'),
#  ('International', 'NNP'),
#  ('Space', 'NNP'),
#  ('Station', 'NNP'),
#  ('The', 'DT'),
#  ('end', 'NN'),
#  ('financing', 'NN'),
#  ('2025', 'CD'),
#  ('necessarily', 'RB'),
#  ('mean', 'JJ'),
#  ('station', 'NN'),
#  ('would', 'MD'),
#  ('discarded', 'VB'),
#  ('The', 'DT'),
#  ('Washington', 'NNP'),
#  ('Post', 'NNP'),
#  ('reported', 'VBD'),
#  ('Sunday', 'NNP'),
#  ('internal', 'JJ'),
#  ('NASA', 'NNP'),
#  ('document', 'NN'),
#  ('asserts', 'VBZ'),
#  ('â€śIt', 'RBR'),
#  ('possible', 'JJ'),
#  ('industry', 'NN'),
#  ('could', 'MD'),
#  ('continue', 'VB'),
#  ('operate', 'VB'),
#  ('certain', 'JJ'),
#  ('elements', 'NNS'),
#  ('capabilities', 'NNS'),
#  ('ISS', 'NNP'),
#  ('part', 'NN'),
#  ('future', 'NN'),
#  ('commercial', 'JJ'),
#  ('platform.â€ť', 'NN'),
#  ('But', 'CC'),
#  ('space', 'NN'),
#  ('experts', 'NNS'),
#  ('far', 'RB'),
#  ('see', 'VB'),
#  ('would', 'MD'),
#  ('viable', 'VB'),
#  ('economically', 'RB'),
#  ('NASA', 'NNP'),
#  ('currently', 'RB'),
#  ('spends', 'VBZ'),
#  ('3', 'CD'),
#  ('billion', 'CD'),
#  ('4', 'CD'),
#  ('billion', 'CD'),
#  ('year', 'NN'),
#  ('â€śI', 'NNP'),
#  ('really', 'RB'),
#  ('seen', 'VBN'),
#  ('anyone', 'NN'),
#  ('talking', 'VBG'),
#  ('â€ť', 'NNP'),
#  ('said', 'VBD'),
#  ('Tommy', 'NNP'),
#  ('Sanford', 'NNP'),
#  ('executive', 'NN'),
#  ('director', 'NN'),
#  ('Commercial', 'NNP'),
#  ('Spaceflight', 'NNP'),
#  ('Federation', 'NNP'),
#  ('trade', 'NN'),
#  ('group', 'NN'),
#  ('representing', 'VBG'),
#  ('many', 'JJ'),
#  ('new', 'JJ'),
#  ('space', 'NN'),
#  ('companies', 'NNS'),
#  ('â€śI', 'VBP'),
#  ('think', 'VBP'),
#  ("that'd", 'JJ'),
#  ('difficult.â€ť', 'VBP'),
#  ('Mr.', 'NNP'),
#  ('Sanford', 'NNP'),
#  ('said', 'VBD'),
#  ('federation', 'NN'),
#  ('concerned', 'VBN'),
#  ('setting', 'VBG'),
#  ('specific', 'JJ'),
#  ('end', 'NN'),
#  ('date', 'NN'),
#  ('He', 'PRP'),
#  ('said', 'VBD'),
#  ('would', 'MD'),
#  ('better', 'VB'),
#  ('define', 'VB'),
#  ('benchmarks', 'JJ'),
#  ('commercial', 'JJ'),
#  ('alternatives', 'NNS'),
#  ('would', 'MD'),
#  ('need', 'VB'),
#  ('achieve', 'VB'),
#  ('International', 'NNP'),
#  ('Space', 'NNP'),
#  ('Station', 'NNP'),
#  ('retired', 'VBD'),
#  ('In', 'IN'),
#  ('recent', 'JJ'),
#  ('years', 'NNS'),
#  ('companies', 'NNS'),
#  ('started', 'VBD'),
#  ('using', 'VBG'),
#  ('station', 'NN'),
#  ('areas', 'NNS'),
#  ('like', 'IN'),
#  ('pharmaceutical', 'JJ'),
#  ('research', 'NN'),
#  ('manufacturing', 'NN'),
#  ('fiber', 'VB'),
#  ('optical', 'JJ'),
#  ('cable', 'NN'),
#  ('â€śIf', 'NN'),
#  ('abruptly', 'RB'),
#  ('end', 'VB'),
#  ('without', 'IN'),
#  ('smooth', 'JJ'),
#  ('transition', 'NN'),
#  ('plan', 'NN'),
#  ('â€ť', 'NNP'),
#  ('John', 'NNP'),
#  ('Elbon', 'NNP'),
#  ('vice', 'NN'),
#  ('president', 'NN'),
#  ('general', 'JJ'),
#  ('manager', 'NN'),
#  ('space', 'NN'),
#  ('exploration', 'NN'),
#  ('Boeing', 'NNP'),
#  ('said', 'VBD'),
#  ('last', 'JJ'),
#  ("week's", 'JJ'),
#  ('conference', 'NN'),
#  ('â€śall', 'NN'),
#  ('investment', 'NN'),
#  ('naught.â€ť', 'NN'),
#  ('For', 'IN'),
#  ('greater', 'JJR'),
#  ('focus', 'NN'),
#  ('moon', 'NN'),
#  ('budget', 'NN'),
#  ('plan', 'NN'),
#  ('describes', 'VBZ'),
#  ('investing', 'VBG'),
#  ('commercial', 'JJ'),
#  ('companies', 'NNS'),
#  ('develop', 'VBP'),
#  ('fly', 'JJ'),
#  ('robotic', 'JJ'),
#  ('landers', 'NNS'),
#  ('carry', 'VBP'),
#  ('experiments', 'NNS'),
#  ('payloads', 'NNS'),
#  ('moon', 'VBP'),
#  ('Those', 'DT'),
#  ('companies', 'NNS'),
#  ('could', 'MD'),
#  ('include', 'VB'),
#  ('Moon', 'NNP'),
#  ('Express', 'NNP'),
#  ('Astrobotic', 'NNP'),
#  ('Technology', 'NNP'),
#  ('two', 'CD'),
#  ('companies', 'NNS'),
#  ('originally', 'RB'),
#  ('created', 'VBD'),
#  ('compete', 'JJ'),
#  ('20', 'CD'),
#  ('million', 'CD'),
#  ('grand', 'JJ'),
#  ('prize', 'NN'),
#  ('Google', 'NNP'),
#  ('Lunar', 'NNP'),
#  ('X', 'NNP'),
#  ('Prize', 'NNP'),
#  ('The', 'DT'),
#  ('X', 'NNP'),
#  ('Prize', 'NNP'),
#  ('Foundation', 'NNP'),
#  ('conceded', 'VBD'),
#  ('last', 'JJ'),
#  ('month', 'NN'),
#  ('none', 'NN'),
#  ('remaining', 'VBG'),
#  ('competitors', 'NNS'),
#  ('would', 'MD'),
#  ('able', 'JJ'),
#  ('reach', 'VB'),
#  ('moon', 'JJ'),
#  ('prize', 'NN'),
#  ('expires', 'VBZ'),
#  ('March', 'NNP'),
#  ('31', 'CD'),
#  ('Both', 'NNP'),
#  ('companies', 'NNS'),
#  ('still', 'RB'),
#  ('plan', 'VBP'),
#  ('head', 'VBP'),
#  ('moon', 'NN'),
#  ('next', 'JJ'),
#  ('couple', 'NN'),
#  ('years', 'NNS'),
#  ('In', 'IN'),
#  ('addition', 'NN'),
#  ('Blue', 'NNP'),
#  ('Origin', 'NNP'),
#  ('space', 'NN'),
#  ('company', 'NN'),
#  ('started', 'VBD'),
#  ('Jeff', 'NNP'),
#  ('Bezos', 'NNP'),
#  ('chief', 'JJ'),
#  ('executive', 'NN'),
#  ('Amazon', 'NNP'),
#  ('proposed', 'VBD'),
#  ('larger', 'JJR'),
#  ('lander', 'NN'),
#  ('called', 'VBN'),
#  ('Blue', 'NNP'),
#  ('Moon', 'NNP'),
#  ('could', 'MD'),
#  ('deliver', 'VB'),
#  ('several', 'JJ'),
#  ('tons', 'NNS'),
#  ('cargo', 'VBP'),
#  ('surface', 'NN'),
#  ('moon', 'NN'),
#  ('Efforts', 'NNP'),
#  ('increase', 'NN'),
#  ('research', 'NN'),
#  ('development', 'NN'),
#  ('aimed', 'VBD'),
#  ('next-generation', 'JJ'),
#  ('space', 'NN'),
#  ('technologies', 'NNS'),
#  ('range', 'VBP'),
#  ('human', 'JJ'),
#  ('robotic', 'JJ'),
#  ('missions', 'NNS'),
#  ('one', 'CD'),
#  ('priorities', 'NNS'),
#  ('Obama', 'NNP'),
#  ("administration's", 'VBD'),
#  ('space', 'NN'),
#  ('policy', 'NN'),
#  ('would', 'MD'),
#  ('refocused', 'VB'),
#  ('nearer-term', 'JJ'),
#  ('development', 'NN'),
#  ('moon', 'NN'),
#  ('missions', 'NNS'),
#  ('For', 'IN'),
#  ('astronauts', 'NNS'),
#  ('goal', 'NN'),
#  ('still', 'RB'),
#  ('reach', 'VB'),
#  ('â€śthe', 'JJ'),
#  ('vicinity', 'NN'),
#  ('moonâ€ť', 'NN'),
#  ('2023', 'CD'),
#  ('That', 'WDT'),
#  ('current', 'JJ'),
#  ('schedule', 'NN'),
#  ('first', 'RB'),
#  ('crewed', 'VBD'),
#  ('launch', 'JJ'),
#  ('Space', 'NNP'),
#  ('Launch', 'NNP'),
#  ('System', 'NNP'),
#  ('would', 'MD'),
#  ('fly', 'VB'),
#  ('around', 'IN'),
#  ('moon', 'NN'),
#  ('land', 'NN'),
#  ('Under', 'IN'),
#  ('proposed', 'VBN'),
#  ('timeline', 'NN'),
#  ('work', 'NN'),
#  ('lander', 'NN'),
#  ('would', 'MD'),
#  ('start', 'VB'),
#  ('year', 'NN')]

# %%
def customPattern(tagged):
    my_entities = []
    entity = []
    for tagged_entry in tagged:
        if(tagged_entry[1].startswith("NN") or (entity and tagged_entry[1].startswith("IN"))):
            entity.append(tagged_entry)
        else:
            if(entity) and entity[-1][1].startswith("IN"):
                entity.pop()
            if(entity and " ".join(e[0] for e in entity)[0].isupper()):
                my_entities.append(" ".join(e[0] for e in entity))
            entity = []
    return my_entities

# %%
def extractEntities(ne_chunked):
    data = []
    for entity in ne_chunked:
        if isinstance(entity, nltk.tree.Tree):
            data.append(" ".join([word for word, tag in entity.leaves()]))
        else:
            continue
    return data

# %%
my_entities = customPattern(tagged)
for entity in my_entities:
    try:
        page = wikipedia.page(entity)
        print(entity)
        print(page.summary.split(".")[0])
    except:
        print(entity)
        print("Unknown")
    print("\n")
# Out:
# NASA
# The National Aeronautics and Space Administration (NASA ) is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research
#
#
# Monday
# Monday is the day of the week between Sunday and Tuesday
#
#
# New York Times
# The New York Times (sometimes abbreviated as The NYT or The Times) is an American newspaper based in New York City with worldwide influence and readership
#
#
# Oct.
# October is the tenth month of the year in the Julian and Gregorian Calendars and the sixth of seven months to have a length of 31 days
#
#
# Congress
# A congress is a formal meeting of the representatives of different nations, constituent states, organizations (such as trade unions, and political parties), or groups
#
#
# Mr. Trump
# Trump is a surname of English and German origin:
# a German surname, from a word for "drum"; it is notable as the surname of the American entrepreneurial Trump family, but has an older presence in the United States via the 18th-century Amish migration from the Palatinate to Pennsylvania
#
#
# NASA's
# The National Aeronautics and Space Administration (NASA ) is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research
#
#
# One Owns Moon
# Neil Alden Armstrong (August 5, 1930 – August 25, 2012) was an American astronaut and aeronautical engineer, and the first person to walk on the Moon
#
#
# Make Money
# Make Money is a studio album released in 1996 by the Washington, D
#
#
# NOV.
# November is the eleventh and penultimate month of the year in the Julian and Gregorian Calendars, the fourth and last of four months to have a length of 30 days, and the fifth and last of five months to have a length of less than 31 days
#
#
# Falcon Heavy Roar Thunder Carries SpaceX's Ambition Into Orbit FEB.
# Falcon Heavy is a partially reusable super heavy-lift launch vehicle designed and manufactured by SpaceX
#
#
# Google Lunar X Prize's Race Moon
# Unknown
#
#
# Nobody Won JAN.
# The following is a list of SingStar games released for the PlayStation 2 video game console
#
#
# RECENT COMMENTS Bill February
# Unknown
#
#
# Predictably Trump regime
# Unknown
#
#
# NASA funding
# As a federal agency, the National Aeronautics and Space Administration (NASA) receives its funding from the annual federal budget passed by the United States Congress
#
#
# February
# February is the second and shortest month of the year in the Julian and Gregorian calendar with 28 days in common years and 29 days in leap years, with the quadrennial 29th day being called the leap day
#
#
# Climate change denier
# Climate change denial, or global warming denial, is part of the global warming controversy
#
#
# Navy pilot As line
# This is a list of Royal Doulton figurines in ascending order by HN number
#
#
# February
# February is the second and shortest month of the year in the Julian and Gregorian calendar with 28 days in common years and 29 days in leap years, with the quadrennial 29th day being called the leap day
# c:\users\bakajvo1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\bakajvo1\appdata\local\programs\python\python36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# Who
# Unknown
#
#
# Elon Musk
# Elon Reeve Musk (; born June 28, 1971) is a South African-born Canadian American business magnate, investor, and engineer
#
#
# Mars
# Mars is the fourth planet from the Sun and the second-smallest planet in the Solar System after Mercury
#
#
# SEE ALL COMMENTS A NASA spokesman
# Unknown
#
#
# NASA's budget
# As a federal agency, the National Aeronautics and Space Administration (NASA) receives its funding from the annual federal budget passed by the United States Congress
#
#
# Jim Bridenstine Oklahoma congressman
# James Frederick Bridenstine (born June 15, 1975) is an American politician who has been the United States Representative for Oklahoma's 1st congressional district, based in Tulsa, since 2013
#
#
# Whether administration votes
# Unknown
#
#
# Trump administration
# Donald Trump was inaugurated as the 45th President of the United States at noon EST on January 20, 2017, succeeding Barack Obama
#
#
# National Space Council
# The National Space Council is a body within the Executive Office of the President of the United States that was created in 1989 during the administration of George H
#
#
# Vice President Mike Pence
# Michael Richard Pence (born June 7, 1959) is an American politician and lawyer serving as the 48th and current Vice President of the United States, since January 20, 2017
#
#
# Trump administration
# Donald Trump was inaugurated as the 45th President of the United States at noon EST on January 20, 2017, succeeding Barack Obama
#
#
# Trump administration
# Donald Trump was inaugurated as the 45th President of the United States at noon EST on January 20, 2017, succeeding Barack Obama
#
#
# Congress
# A congress is a formal meeting of the representatives of different nations, constituent states, organizations (such as trade unions, and political parties), or groups
#
#
# Verge outlets
# Unknown
#
#
# Republicans
# Unknown
#
#
# Bigfoot Senator Ted Cruz Republican Texas chairman Senate Subcommittee Space Science Competitiveness
# Unknown
#
#
# Wednesday Federal Aviation Administration conference
# The city of Allentown, Pennsylvania was established in 1762 and is one of the oldest major cities in the Commonwealth of Pennsylvania and the United States
#
#
# Scott Pace executive secretary Mr. Pence's space council While discuss details budget Mr. Pace
# Ronald Wilson Reagan (; February 6, 1911 – June 5, 2004) was an American politician and actor who served as the 40th President of the United States from 1981 to 1989
#
#
# NASA
# The National Aeronautics and Space Administration (NASA ) is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research
#
#
# International Space Station
# The International Space Station (ISS) is a space station, or a habitable artificial satellite, in low Earth orbit
#
#
# Washington Post
# The Washington Post is an American daily newspaper
#
#
# Sunday
# Sunday is the day of the week after Saturday but before Monday
#
#
# NASA document
# The National Aeronautics and Space Administration (NASA ) is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research
#
#
# NASA
# The National Aeronautics and Space Administration (NASA ) is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research
#
#
# Tommy Sanford executive director Commercial Spaceflight Federation trade group
# Unknown
#
#
# Mr. Sanford
# Fred G
#
#
# International Space Station
# The International Space Station (ISS) is a space station, or a habitable artificial satellite, in low Earth orbit
#
#
# Moon Express Astrobotic Technology
# The following outline is provided as an overview of and topical guide to the Moon:
# Moon – Earth's only permanent natural satellite
#
#
# X Prize Foundation
# XPRIZE is a nonprofit organization that designs and manages public competitions intended to encourage technological development that could benefit humanity
#
#
# March
# March is the third month of the year in both the Julian and Gregorian calendars
#
#
# Both companies
# The automotive industry is a wide range of companies and organizations involved in the design, development, manufacturing, marketing, and selling of motor vehicles, some of them are called automakers
#
#
# Jeff Bezos
# Jeffrey Preston Bezos (; né Jorgensen; born January 12, 1964) is an American technology entrepreneur, investor, and philanthropist, best known as the founder, chairman, and chief executive officer of Amazon, the world's largest online shopping retailer
#
#
# Blue Moon
# A blue moon is an additional full moon that appears in a subdivision of a year: either the third of four full moons in a season, or a second full moon in a month of the common calendar
#
#
# Space Launch System
# The Space Launch System (SLS) is an American Space Shuttle-derived heavy-lift expendable launch vehicle

# %%
def wikipediaClassification(entity):
    try:
        page = wikipedia.page(entity)
        summary = page.summary.split(".")[0]
    except:
        return "Thing"
    
    tokens = preprocessText(summary)
    tagged = nltk.pos_tag(tokens)
    ne_chunked = nltk.ne_chunk(tagged)
    res = " ".join(extractEntities(ne_chunked))
    if not res:
        return "Thing"
    else:
        return res

def wikipediaClassificationCustom(entity):
    try:
        page = wikipedia.page(entity)
        summary = page.summary.split(".")[0]
    except:
        return "Thing"
    
    tokens = preprocessText(summary)
    tagged = nltk.pos_tag(tokens)
    ne_chunked = customPattern(tagged)
    res = " ".join(ne_chunked)
    if not res:
        return "Thing"
    else:
        return res

# %%
def processEntities(ne_chunked):
    df = pd.DataFrame(columns=["Entity", "Nltk-based Class", "Wiki-based Class using nltk entities", "Wiki-based Class using custom entities"])
    for entity in ne_chunked:
        if isinstance(entity, nltk.tree.Tree):
            text = " ".join([word for word, tag in entity.leaves()])
            ent = entity.label()
            wiki_nltk = wikipediaClassification(text)
            wiki_custom = wikipediaClassificationCustom(text)
            df = df.append({"Entity": text,
                            "Nltk-based Class": ent,
                            "Wiki-based Class using nltk entities": wiki_nltk,
                            "Wiki-based Class using custom entities": wiki_custom}, ignore_index=True)
            #print(".")
        else:
            continue
    return df

# %%
ne_chunked = nltk.ne_chunk(tagged, binary=False)
processEntities(ne_chunked)
# Out:
# c:\users\bakajvo1\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\bakajvo1\appdata\local\programs\python\python36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
#                                                Entity Nltk-based Class  \
# 0                                               Trump           PERSON
# 1                                                NASA     ORGANIZATION
# 2                                            American              GPE
# 3                                 International Space     ORGANIZATION
# 4                                                NASA     ORGANIZATION
# 5                                      New York Times              GPE
# 6                                            Congress     ORGANIZATION
# 7                                           Mr. Trump           PERSON
# 8                                             RELATED     ORGANIZATION
# 9                                    No One Owns Moon     ORGANIZATION
# 10                                         Make Money           PERSON
# 11                                         Into Orbit     ORGANIZATION
# 12                                       Google Lunar     ORGANIZATION
# 13                                         Nobody Won           PERSON
# 14                                             RECENT     ORGANIZATION
# 15                                           COMMENTS     ORGANIZATION
# 16                                               Bill           PERSON
# 17                                               NASA     ORGANIZATION
# 18                                               NASA     ORGANIZATION
# 19                                            Climate     ORGANIZATION
# 20                                          Elon Musk           PERSON
# 21                                               Mars           PERSON
# 22                                                SEE     ORGANIZATION
# 23                                               NASA     ORGANIZATION
# 24                                           Congress     ORGANIZATION
# 25                                          Mr. Trump           PERSON
# 26                           Jim Bridenstine Oklahoma           PERSON
# 27                                             Senate     ORGANIZATION
# 28                                            Whether           PERSON
# 29                                              Trump     ORGANIZATION
# 30                             National Space Council     ORGANIZATION
# 31                                         Mike Pence           PERSON
# 32                                              Trump     ORGANIZATION
# 33             Plankton Aerosol Cloud Ocean Ecosystem           PERSON
# 34                                               NASA     ORGANIZATION
# 35                                              Trump     ORGANIZATION
# 36                                           Congress     ORGANIZATION
# 37                                              Verge     ORGANIZATION
# 38          Bigfoot Senator Ted Cruz Republican Texas           PERSON
# 39  Senate Subcommittee Space Science Competitiveness     ORGANIZATION
# 40                                        White House         FACILITY
# 41                                         Scott Pace           PERSON
# 42                                                Mr.           PERSON
# 43                                           Mr. Pace           PERSON
# 44                                               NASA     ORGANIZATION
# 45                                               NASA     ORGANIZATION
# 46                                      United States              GPE
# 47                                International Space     ORGANIZATION
# 48                                    Washington Post     ORGANIZATION
# 49                                               NASA     ORGANIZATION
# 50                                                ISS     ORGANIZATION
# 51                                               NASA     ORGANIZATION
# 52                                      Tommy Sanford           PERSON
# 53                  Commercial Spaceflight Federation     ORGANIZATION
# 54                                        Mr. Sanford           PERSON
# 55                        International Space Station     ORGANIZATION
# 56                                         John Elbon           PERSON
# 57                                             Boeing           PERSON
# 58                            Moon Express Astrobotic           PERSON
# 59                                       Google Lunar           PERSON
# 60                                        Blue Origin           PERSON
# 61                                         Jeff Bezos           PERSON
# 62                                             Amazon           PERSON
# 63                                          Blue Moon           PERSON
# 64                                            Efforts           PERSON
# 65                                              Obama           PERSON
# 66                                Space Launch System           PERSON
#
#                  Wiki-based Class using nltk entities  \
# 0                                               Thing
# 1   National Aeronautics Space Administration NASA...
# 2                                               Thing
# 3                         International Space Station
# 4   National Aeronautics Space Administration NASA...
# 5         New York Times Times American New York City
# 6                                               Thing
# 7   Trump English German German American Trump Uni...
# 8                                 Related American WB
# 9                  Neil Alden Armstrong American Moon
# 10                            Make Money Washington D
# 11                                              Thing
# 12                                       Google Lunar
# 13                                              Thing
# 14                                           Holocene
# 15                        French Medieval Latin Latin
# 16                                              Thing
# 17  National Aeronautics Space Administration NASA...
# 18  National Aeronautics Space Administration NASA...
# 19                                            Climate
# 20            Elon Reeve Musk South Canadian American
# 21                          Mars Solar System Mercury
# 22                                              Thing
# 23  National Aeronautics Space Administration NASA...
# 24                                              Thing
# 25  Trump English German German American Trump Uni...
# 26  James Frederick Bridenstine American United St...
# 27                                              Thing
# 28                                              Thing
# 29                                              Thing
# 30  National Space Council Executive Office United...
# 31       Michael Richard Pence American United States
# 32                                              Thing
# 33                        Plankton Aerosol Cloud NASA
# 34  National Aeronautics Space Administration NASA...
# 35                                              Thing
# 36                                              Thing
# 37                           Verge American Vox Media
# 38                            Clinton Howard American
# 39  Senate Commerce Subcommittee Space Science Sen...
# 40                          White House United States
# 41  Scott Norman Pace Executive Director National ...
# 42                                             Mister
# 43                                              Thing
# 44  National Aeronautics Space Administration NASA...
# 45  National Aeronautics Space Administration NASA...
# 46                United States America United States
# 47                        International Space Station
# 48                           Washington Post American
# 49  National Aeronautics Space Administration NASA...
# 50                        International Space Station
# 51  National Aeronautics Space Administration NASA...
# 52                           Marshall Mark Sanford Jr
# 53                  Commercial Spaceflight Federation
# 54                                               Fred
# 55                        International Space Station
# 56                                              Thing
# 57                            Boeing Company American
# 58                                    Moon Moon Earth
# 59                                       Google Lunar
# 60           Blue Origin LLC American Kent Washington
# 61              Jeffrey Preston Bezos American Amazon
# 62                                              Thing
# 63                                              Thing
# 64                                              Thing
# 65        Barack Hussein Obama American United States
# 66                 Space Launch System American Space
#
#                Wiki-based Class using custom entities
# 0                                               Thing
# 1      National Aeronautics Space Administration NASA
# 2                                               Thing
# 3       International Space Station ISS space station
# 4      National Aeronautics Space Administration NASA
# 5   New York Times NYT Times American newspaper Ne...
# 6                                               Thing
# 7   Trump surname German German surname word Trump...
# 8                                          WB network
# 9                         Neil Alden Armstrong August
# 10                            Make Money studio album
# 11                                              Thing
# 12                      Google Lunar XPRIZE GLXP Moon
# 13                                              Thing
# 14                                           Holocene
# 15                                              Thing
# 16                                              Thing
# 17     National Aeronautics Space Administration NASA
# 18     National Aeronautics Space Administration NASA
# 19                                 Climate statistics
# 20                         Elon Reeve Musk June South
# 21                                               Mars
# 22                                              Thing
# 23     National Aeronautics Space Administration NASA
# 24                                              Thing
# 25  Trump surname German German surname word Trump...
# 26             James Frederick Bridenstine June Tulsa
# 27                                              Thing
# 28                                              Thing
# 29                                              Thing
# 30  National Space Council body within Executive O...
# 31  Michael Richard Pence June Vice President Unit...
# 32                                              Thing
# 33         Plankton Aerosol Cloud Ecosystem PACE NASA
# 34     National Aeronautics Space Administration NASA
# 35                                              Thing
# 36                                              Thing
# 37       Verge American technology news media network
# 38                               Clinton Howard April
# 39  Senate Commerce Subcommittee Space Science Com...
# 40                                              Thing
# 41                          Scott Norman Pace January
# 42                                             Mister
# 43                                              Thing
# 44     National Aeronautics Space Administration NASA
# 45     National Aeronautics Space Administration NASA
# 46                          United States America USA
# 47      International Space Station ISS space station
# 48                           Washington Post American
# 49     National Aeronautics Space Administration NASA
# 50      International Space Station ISS space station
# 51     National Aeronautics Space Administration NASA
# 52                              Marshall Clement Mark
# 53                  Commercial Spaceflight Federation
# 54                                              Thing
# 55      International Space Station ISS space station
# 56                                              Thing
# 57                            Boeing Company American
# 58                                              Thing
# 59                      Google Lunar XPRIZE GLXP Moon
# 60                           Blue Origin LLC American
# 61  Jeffrey Preston Bezos Jorgensen January Americ...
# 62                                              Thing
# 63                                              Thing
# 64                                              Thing
# 65  Barack Hussein Obama II August President Unite...
# 66  Space Launch System SLS Space Shuttle-derived ...

# %%
def counts(entities):
    counts = Counter(entities)
    sortedCounts = sorted(counts.items(), key=lambda count:count[1], reverse=True)
    return sortedCounts

# %%
counts(customPattern(tagged))
# Out:
# [('NASA', 3),
#  ('Trump administration', 3),
#  ('Congress', 2),
#  ('February', 2),
#  ('International Space Station', 2),
#  ('Monday', 1),
#  ('New York Times', 1),
#  ('Oct.', 1),
#  ('Mr. Trump', 1),
#  ("NASA's", 1),
#  ('One Owns Moon', 1),
#  ('Make Money', 1),
#  ('NOV.', 1),
#  ("Falcon Heavy Roar Thunder Carries SpaceX's Ambition Into Orbit FEB.", 1),
#  ("Google Lunar X Prize's Race Moon", 1),
#  ('Nobody Won JAN.', 1),
#  ('RECENT COMMENTS Bill February', 1),
#  ('Predictably Trump regime', 1),
#  ('NASA funding', 1),
#  ('Climate change denier', 1),
#  ('Navy pilot As line', 1),
#  ('Who', 1),
#  ('Elon Musk', 1),
#  ('Mars', 1),
#  ('SEE ALL COMMENTS A NASA spokesman', 1),
#  ("NASA's budget", 1),
#  ('Jim Bridenstine Oklahoma congressman', 1),
#  ('Whether administration votes', 1),
#  ('National Space Council', 1),
#  ('Vice President Mike Pence', 1),
#  ('Verge outlets', 1),
#  ('Republicans', 1),
#  ('Bigfoot Senator Ted Cruz Republican Texas chairman Senate Subcommittee Space Science Competitiveness',
#   1),
#  ('Wednesday Federal Aviation Administration conference', 1),
#  ("Scott Pace executive secretary Mr. Pence's space council While discuss details budget Mr. Pace",
#   1),
#  ('Washington Post', 1),
#  ('Sunday', 1),
#  ('NASA document', 1),
#  ('Tommy Sanford executive director Commercial Spaceflight Federation trade group',
#   1),
#  ('Mr. Sanford', 1),
#  ('Moon Express Astrobotic Technology', 1),
#  ('X Prize Foundation', 1),
#  ('March', 1),
#  ('Both companies', 1),
#  ('Jeff Bezos', 1),
#  ('Blue Moon', 1),
#  ('Space Launch System', 1)]

# %%
ne_chunked = nltk.ne_chunk(tagged)
counts(extractEntities(ne_chunked))
# Out:
# [('NASA', 10),
#  ('Trump', 4),
#  ('Congress', 3),
#  ('International Space', 2),
#  ('Mr. Trump', 2),
#  ('Google Lunar', 2),
#  ('American', 1),
#  ('New York Times', 1),
#  ('RELATED', 1),
#  ('No One Owns Moon', 1),
#  ('Make Money', 1),
#  ('Into Orbit', 1),
#  ('Nobody Won', 1),
#  ('RECENT', 1),
#  ('COMMENTS', 1),
#  ('Bill', 1),
#  ('Climate', 1),
#  ('Elon Musk', 1),
#  ('Mars', 1),
#  ('SEE', 1),
#  ('Jim Bridenstine Oklahoma', 1),
#  ('Senate', 1),
#  ('Whether', 1),
#  ('National Space Council', 1),
#  ('Mike Pence', 1),
#  ('Plankton Aerosol Cloud Ocean Ecosystem', 1),
#  ('Verge', 1),
#  ('Bigfoot Senator Ted Cruz Republican Texas', 1),
#  ('Senate Subcommittee Space Science Competitiveness', 1),
#  ('White House', 1),
#  ('Scott Pace', 1),
#  ('Mr.', 1),
#  ('Mr. Pace', 1),
#  ('United States', 1),
#  ('Washington Post', 1),
#  ('ISS', 1),
#  ('Tommy Sanford', 1),
#  ('Commercial Spaceflight Federation', 1),
#  ('Mr. Sanford', 1),
#  ('International Space Station', 1),
#  ('John Elbon', 1),
#  ('Boeing', 1),
#  ('Moon Express Astrobotic', 1),
#  ('Blue Origin', 1),
#  ('Jeff Bezos', 1),
#  ('Amazon', 1),
#  ('Blue Moon', 1),
#  ('Efforts', 1),
#  ('Obama', 1),
#  ('Space Launch System', 1)]
